# %% [markdown]
# <h2> Data Preprocessing</h2>

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_matrix = pd.read_csv("D:/aRIMA/06-06/ARIMA-Latur-master/ARIMA-Latur-master/LaturRains_1965_2002.csv",sep="\t")
type(data_matrix)
# Out:
# pandas.core.frame.DataFrame

# %%
data_matrix.set_index('Year', inplace=True)
data_matrix = data_matrix.transpose()
data_matrix.head()
# Out:
# Year   1965    1966    1967    1968   1969    1970    1971    1972   1973  \
# Jan   0.272   5.439   1.318   2.708  0.000   3.224   0.168   0.000  0.000
# Feb   0.082   1.949   0.705  54.213  0.000   0.000   0.000   0.649  0.092
# Mar   0.000   4.044   3.735  35.990  0.804   0.000   0.660   0.025  0.000
# Apr   2.093   5.869   1.509   3.302  4.353  26.318   1.926   9.806  3.731
# May   0.966  10.855  45.454   8.995  9.161  31.172  31.948  13.941  1.903
#
# Year    1974  ...   1993    1994    1995    1996    1997    1998    1999  \
# Jan    0.000  ...  0.000  12.229  14.457   0.376  11.575   0.000   0.000
# Feb    0.000  ...  1.527   6.256   0.000   3.540   0.000   2.786   8.173
# Mar    0.424  ...  2.011   7.880  22.736   1.496   6.189   0.760   0.000
# Apr    5.076  ...  5.291  29.439   2.986  20.172  34.975   1.652   2.979
# May   10.591  ...  5.426  14.410  47.057   5.589   9.236  10.623  67.643
#
# Year    2000    2001    2002
# Jan    0.000   7.385  10.846
# Feb    6.343   0.000   0.324
# Mar    0.000  28.177   4.526
# Apr    4.299   6.978  22.799
# May   35.362   4.065  26.652
#
# [5 rows x 38 columns]

# %%
dates = pd.date_range(start='1965-01', freq='MS', periods=len(data_matrix.columns)*12)
dates
# Out:
# DatetimeIndex(['1965-01-01', '1965-02-01', '1965-03-01', '1965-04-01',
#                '1965-05-01', '1965-06-01', '1965-07-01', '1965-08-01',
#                '1965-09-01', '1965-10-01',
#                ...
#                '2002-03-01', '2002-04-01', '2002-05-01', '2002-06-01',
#                '2002-07-01', '2002-08-01', '2002-09-01', '2002-10-01',
#                '2002-11-01', '2002-12-01'],
#               dtype='datetime64[ns]', length=456, freq='MS')

# %%
rainfall_data_matrix_np = data_matrix.transpose().as_matrix()

shape = rainfall_data_matrix_np.shape
rainfall_data_matrix_np = rainfall_data_matrix_np.reshape((shape[0] * shape[1], 1))
# Out:
# C:\Users\mihir.dakwala\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
rainfall_data = pd.DataFrame({'Precipitation': rainfall_data_matrix_np[:,0]})
rainfall_data.set_index(dates, inplace=True)

plt.figure(figsize=(20,5))
plt.plot(rainfall_data, color='blue')
plt.xlabel('Year')
plt.ylabel('Precipitation(mm)')
plt.title('Precipitation in mm')
test_data = rainfall_data.ix['1995': '2002']
train_data = rainfall_data.ix[: '1994']
type(train_data)
# Out:
# C:\Users\mihir.dakwala\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# C:\Users\mihir.dakwala\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':
# C:\Users\mihir.dakwala\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# pandas.core.frame.DataFrame

# %%
train_data.tail() # 1965-1994
# Out:
#             Precipitation
# 1994-08-01        154.409
# 1994-09-01        114.689
# 1994-10-01        177.968
# 1994-11-01         29.630
# 1994-12-01          0.000

# %%
test_data.head() # 1995-2002
# Out:
#             Precipitation
# 1995-01-01         14.457
# 1995-02-01          0.000
# 1995-03-01         22.736
# 1995-04-01          2.986
# 1995-05-01         47.057

# %% [markdown]
# <h2> Data Plot</h2>

# %%
plt.figure(figsize=(20,5))
plt.plot(rainfall_data, color='blue')
plt.xlabel('Year')
plt.ylabel('Precipitation(mm)')
plt.title('Precipitation data in mm of Latur from 1965-2002')
# Out:
# Text(0.5, 1.0, 'Precipitation data in mm of Latur from 1965-2002')

# %% [markdown]
# <h2> Building the LSTM Model</h2>

# %%
# Let's load the required libs.
# We'll be using the Tensorflow backend (default).
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers.core import Dense, Activation, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle
from keras.callbacks import LambdaCallback
# Out:
# Using TensorFlow backend.

# %% [markdown]
# <p> Form the data plot, we clearly observe that there is no trend but seasonality component is present.</p>
# <p> Seasonality may be due to the seasonal effects in the climate such as rainy season where more precipitation is expected than in summer or winter.</p>
# <p> Unlike in ARIMA where we need to explicity find out the (P,D,Q) values, we don't need to do such ground work while using neural networks such as LSTMs.</p>
# <p> We transform the data as follows for the reasons provided below</p>
# <ul>
#     <li>Normalize the data for increased numerical stability.</li>
#     <li>Reshape the data so that we have one column for response varible(Y) and another for the predictor(X).</li>
# </ul>

# %% [markdown]
# <b> Data Preparation</b>

# %%
# Get the raw data values from the pandas data frame.
data_raw = rainfall_data.values.astype("float32")

scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(data_raw)

# Print a few values.
dataset[0:5]
# Out:
# array([[0.00058702],
#        [0.00017697],
#        [0.        ],
#        [0.00451701],
#        [0.00208477]], dtype=float32)

# %% [markdown]
# <b>Split Data into Train and Test datasets</b>

# %%
#using 80% of data to train amd 20% to test

TRAIN_SIZE = 0.8
train_size = int(len(dataset)*TRAIN_SIZE)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]
print (dataset.shape)
print (train.shape)
print (test.shape)
print("Number of entries (training set, test set): " + str((len(train), len(test))))
# Out:
# (456, 1)
# (364, 1)
# (92, 1)
# Number of entries (training set, test set): (364, 92)

# %%
def create_dataset(dataset, window_size = 1):
    data_X, data_Y = [], []
    for i in range(len(dataset) - window_size - 1):
        a = dataset[i:(i + window_size), 0]
        data_X.append(a)
#         print("--",dataset[i+window_size,0],"--")
        data_Y.append(dataset[i + window_size, 0])
    return(np.array(data_X), np.array(data_Y))

# %%
# Create test and training sets for one-step-ahead regression.
window_size = 12
train_X, train_Y = create_dataset(train, window_size)
test_X, test_Y = create_dataset(test, window_size)
print("Original training data shape:")
# print(train_Y)
print(train_X.shape)
print(train_Y.shape)

# Reshape the input data into appropriate form for Keras.
train_X = np.reshape(train_X, (train_X.shape[0], 1, train_X.shape[1]))
test_X = np.reshape(test_X, (test_X.shape[0], 1, test_X.shape[1]))
train_Y = np.reshape(train_Y, (train_Y.shape[0], 1))
test_Y = np.reshape(test_Y, (test_Y.shape[0], 1))
print("New training data shape:")
print(train_X.shape)
print(train_Y.shape)
# Out:
# Original training data shape:
# (351, 12)
# (351,)
# New training data shape:
# (351, 1, 12)
# (351, 1)

# %%
# train_X[:5]

# %% [markdown]
# <b> Build a simple LSTM</b>
# <p>The LSTM architecture here consists of:</p>
# <ul>
# <li>One input layer.</li>
# <li>One LSTM layer of 4 blocks.</li>
# <li>One Dense layer to produce a single output.</li>
# <li>Use MSE as loss function.</li>
# </ul>
# <p>Many different architectures could be considered. But this is just a quick test, so we'll keep things nice and simple.</p>

# %%
def fit_model(train_X,train_Y,window_size=1):
    
    model = Sequential()
    model.add(LSTM(6,input_shape=(1,window_size)))
#     model.add(LSTM(6,input_shape=(1,window_size)))
    model.add(Dense(1))
#     print_weights = LambdaCallback(on_epoch_end=lambda batch, logs: print(model.layers[0].get_weights()))
    model.compile(loss='mean_squared_error',
                 optimizer='adam', metrics=['mape', 'accuracy'])
#     history = model.fit(train_X,train_Y,validation_data=(test_X, test_Y),epochs=250,batch_size=1,callbacks = [print_weights],verbose=2)
    history = model.fit(train_X,train_Y,validation_data=(test_X, test_Y),epochs=250,batch_size=1,verbose=2)
    return model,history

#     on_epoch_end=lambda batch, logs: print (model.layers[1].get_weights())
#fit the model
model1, history = fit_model(train_X, train_Y, window_size)
plot_model(model1, to_file='LSTM_Latur_plot_1.png', show_shapes=True, show_layer_names=True)
model1.summary()
# Out:
# WARNING:tensorflow:From C:\Users\mihir.dakwala\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\mihir.dakwala\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1188: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From C:\Users\mihir.dakwala\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 351 samples, validate on 79 samples
# Epoch 1/250
# 2s - loss: 0.0330 - mean_absolute_percentage_error: 9853549.0617 - acc: 0.1111 - val_loss: 0.0184 - val_mean_absolute_percentage_error: 7123052.0979 - val_acc: 0.1392
# Epoch 2/250
# 1s - loss: 0.0181 - mean_absolute_percentage_error: 4498962.3014 - acc: 0.1111 - val_loss: 0.0117 - val_mean_absolute_percentage_error: 5654848.8075 - val_acc: 0.1392
# Epoch 3/250
# 1s - loss: 0.0151 - mean_absolute_percentage_error: 4088406.7912 - acc: 0.1111 - val_loss: 0.0108 - val_mean_absolute_percentage_error: 5049200.3629 - val_acc: 0.1392
# Epoch 4/250
# 1s - loss: 0.0144 - mean_absolute_percentage_error: 3729595.6299 - acc: 0.1111 - val_loss: 0.0104 - val_mean_absolute_percentage_error: 4268038.4721 - val_acc: 0.1392
# Epoch 5/250
# 1s - loss: 0.0141 - mean_absolute_percentage_error: 3545957.4306 - acc: 0.1111 - val_loss: 0.0101 - val_mean_absolute_percentage_error: 4042696.0090 - val_acc: 0.1392
# Epoch 6/250
# 1s - loss: 0.0137 - mean_absolute_percentage_error: 3404755.9298 - acc: 0.1111 - val_loss: 0.0100 - val_mean_absolute_percentage_error: 3522392.0592 - val_acc: 0.1392
# Epoch 7/250
# 1s - loss: 0.0135 - mean_absolute_percentage_error: 3014069.3470 - acc: 0.1111 - val_loss: 0.0100 - val_mean_absolute_percentage_error: 3505811.6533 - val_acc: 0.1392
# Epoch 8/250
# 1s - loss: 0.0133 - mean_absolute_percentage_error: 2467812.2541 - acc: 0.1111 - val_loss: 0.0098 - val_mean_absolute_percentage_error: 3035984.8468 - val_acc: 0.1392
# Epoch 9/250
# 1s - loss: 0.0130 - mean_absolute_percentage_error: 2742737.4069 - acc: 0.1111 - val_loss: 0.0096 - val_mean_absolute_percentage_error:
- acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 2384007.4209 - val_acc: 0.1392
# Epoch 70/250
# 1s - loss: 0.0107 - mean_absolute_percentage_error: 2217003.8003 - acc: 0.1111 - val_loss: 0.0082 - val_mean_absolute_percentage_error: 2323874.8662 - val_acc: 0.1392
# Epoch 71/250
# 1s - loss: 0.0107 - mean_absolute_percentage_error: 1695939.5800 - acc: 0.1111 - val_loss: 0.0079 - val_mean_absolute_percentage_error: 1689073.0017 - val_acc: 0.1392
# Epoch 72/250
# 1s - loss: 0.0106 - mean_absolute_percentage_error: 1754252.6188 - acc: 0.1111 - val_loss: 0.0088 - val_mean_absolute_percentage_error: 3224654.2371 - val_acc: 0.1392
# Epoch 73/250
# 1s - loss: 0.0107 - mean_absolute_percentage_error: 1867872.5439 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 1668007.1650 - val_acc: 0.1392
# Epoch 74/250
# 1s - loss: 0.0105 - mean_absolute_percentage_error: 1781362.0333 - acc: 0.1111 - val_loss: 0.0085 - val_mean_absolute_percentage_error: 2639940.6619 - val_acc: 0.1392
# Epoch 75/250
# 1s - loss: 0.0106 - mean_absolute_percentage_error: 1965753.3300 - acc: 0.1111 - val_loss: 0.0083 - val_mean_absolute_percentage_error: 1724316.3473 - val_acc: 0.1392
# Epoch 76/250
# 1s - loss: 0.0109 - mean_absolute_percentage_error: 1680278.6039 - acc: 0.1111 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 1400081.0230 - val_acc: 0.1392
# Epoch 77/250
# 1s - loss: 0.0106 - mean_absolute_percentage_error: 1735571.2829 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 2027830.1046 - val_acc: 0.1392
# Epoch 78/250
# 1s - loss: 0.0104 - mean_absolute_percentage_error: 1861631.8791 - acc: 0.1111 - val_loss: 0.0087 - val_mean_absolute_percentage_error: 2807749.7917 - val_acc: 0.1392
# Epoch 79/250
# 1s - loss: 0.0107 - mean_absolute_percentage_error: 1722672.1811 - acc: 0.1111 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 2162881.8630 - val_acc: 0.1392
# Epoch 80/250
# 1s - loss: 0.0107 - mean_absolute_percentage_error: 1740768.1200 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 1868839.2548 - val_acc: 0.1392
# Epoch 81/250
# 1s - loss: 0.0105 - mean_absolute_percentage_error: 1663712.5441 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 1660116.5246 - val_acc: 0.1392
# Epoch 82/250
# 1s - loss: 0.0107 - mean_absolute_percentage_error: 1729824.2139 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 2206224.3227 - val_acc: 0.1392
# Epoch 83/250
# 1s - loss: 0.0106 - mean_absolute_percentage_error: 1714682.9449 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 1600083.5346 - val_acc: 0.1392
# Epoch 84/250
# 1s - loss: 0.0105 - mean_absolute_percentage_error: 1935146.1779 - acc: 0.1111 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 2824646.2138 - val_acc: 0.1392
# Epoch 85/250
# 1s - loss: 0.0106 - mean_absolute_percentage_error: 1881804.7878 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 1531025.5662 - val_acc: 0.1392
# Epoch 86/250
# 1s - loss: 0.0104 - mean_absolute_percentage_error: 1820344.8794 - acc: 0.1111 - val_loss: 0.0086 - val_mean_absolute_percentage_error: 2647262.7245 - val_acc: 0.1392
# Epoch 87/250
# 1s - loss: 0.0106 - mean_absolute_percentage_error: 1757030.3373 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 1480142.3574 - val_acc: 0.1392
# Epoch 88/250
# 1s - loss: 0.0105 - mean_absolute_percentage_error: 1872977.4901 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 1363872.2618 - val_acc: 0.1392
# Epoch 89/250
# 1s - loss: 0.0104 - mean_absolute_percentage_error: 1604298.4708 - acc: 0.1111 - val_loss: 0.0082 - val_mean_absolute_percentage_error: 3151735.2760 - val_acc: 0.1392
# Epoch 90/250
# 1s - loss: 0.0103 - mean_absolute_percentage_error: 1647613.3568 - acc: 0.1111 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 2821774.0132 - val_acc: 0.1392
# Epoch 91/250
# 1s - loss: 0.0105 - mean_absolute_percentage_error: 1927175.3696 - acc: 0.1111 - val_loss: 0.0082 - val_mean_absolute_percentage_error: 
250
# 1s - loss: 0.0101 - mean_absolute_percentage_error: 1707675.1963 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 1466426.3199 - val_acc: 0.1392
# Epoch 123/250
# 1s - loss: 0.0100 - mean_absolute_percentage_error: 1592795.7790 - acc: 0.1111 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 3703795.2308 - val_acc: 0.1392
# Epoch 124/250
# 1s - loss: 0.0101 - mean_absolute_percentage_error: 1874022.8012 - acc: 0.1111 - val_loss: 0.0079 - val_mean_absolute_percentage_error: 2196878.2455 - val_acc: 0.1392
# Epoch 125/250
# 1s - loss: 0.0101 - mean_absolute_percentage_error: 1662536.3976 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 1327034.4496 - val_acc: 0.1392
# Epoch 126/250
# 1s - loss: 0.0100 - mean_absolute_percentage_error: 1545449.1831 - acc: 0.1111 - val_loss: 0.0085 - val_mean_absolute_percentage_error: 3567738.1302 - val_acc: 0.1392
# Epoch 127/250
# 1s - loss: 0.0100 - mean_absolute_percentage_error: 1595452.4170 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 2579982.6220 - val_acc: 0.1392
# Epoch 128/250
# 1s - loss: 0.0098 - mean_absolute_percentage_error: 2020742.6566 - acc: 0.1111 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 2232398.9240 - val_acc: 0.1392
# Epoch 129/250
# 1s - loss: 0.0100 - mean_absolute_percentage_error: 1589680.1217 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 1695383.4997 - val_acc: 0.1392
# Epoch 130/250
# 1s - loss: 0.0100 - mean_absolute_percentage_error: 1578610.3595 - acc: 0.1111 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 1269523.2396 - val_acc: 0.1392
# Epoch 131/250
# 1s - loss: 0.0100 - mean_absolute_percentage_error: 1531816.3404 - acc: 0.1111 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 2377917.5368 - val_acc: 0.1392
# Epoch 132/250
# 1s - loss: 0.0099 - mean_absolute_percentage_error: 1716411.0801 - acc: 0.1111 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 1725201.7171 - val_acc: 0.1392
# Epoch 133/250
# 1s - loss: 0.0100 - mean_absolute_percentage_error: 1753917.0488 - acc: 0.1111 - val_loss: 0.0079 - val_mean_absolute_percentage_error: 2797810.3202 - val_acc: 0.1392
# Epoch 134/250
# 1s - loss: 0.0099 - mean_absolute_percentage_error: 1317981.9540 - acc: 0.1111 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 1642586.2012 - val_acc: 0.1392
# Epoch 135/250
# 1s - loss: 0.0101 - mean_absolute_percentage_error: 1749528.6942 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 2294295.0931 - val_acc: 0.1392
# Epoch 136/250
# 1s - loss: 0.0100 - mean_absolute_percentage_error: 1571072.9169 - acc: 0.1111 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 1631148.2015 - val_acc: 0.1392
# Epoch 137/250
# 1s - loss: 0.0100 - mean_absolute_percentage_error: 1382146.4548 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 1593049.2297 - val_acc: 0.1392
# Epoch 138/250
# 1s - loss: 0.0099 - mean_absolute_percentage_error: 1740304.6851 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 1336733.1203 - val_acc: 0.1392
# Epoch 139/250
# 1s - loss: 0.0099 - mean_absolute_percentage_error: 1523342.9568 - acc: 0.1111 - val_loss: 0.0085 - val_mean_absolute_percentage_error: 3317255.2481 - val_acc: 0.1392
# Epoch 140/250
# 1s - loss: 0.0100 - mean_absolute_percentage_error: 1549242.4410 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 2178206.2660 - val_acc: 0.1392
# Epoch 141/250
# 1s - loss: 0.0098 - mean_absolute_percentage_error: 1651078.7769 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 2337061.7571 - val_acc: 0.1392
# Epoch 142/250
# 1s - loss: 0.0098 - mean_absolute_percentage_error: 1925520.4422 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 1640489.4345 - val_acc: 0.1392
# Epoch 143/250
# 1s - loss: 0.0098 - mean_absolute_percentage_error: 1539481.2748 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 1873561.8305 - val_acc: 0.1392
# Epoch 144/250
# 1s - loss: 0.0097 - mean_absolute_percentage_error: 1767108.7185 - acc: 0.1111 - val_loss: 0.0083 - val_mean_absolute_percentage_error: 3075074.3878 - val_acc: 0.1392
# Epoch 145/250
# 1s - loss: 0.0099 - mean_absolute_percentage_error: 1717084.4687 - acc: 0.1111 - val_loss: 0.0082 - val_mean_absolute_percentage_error: 3081274.3575 - val_acc: 0.1392
# Epoch 146/250
# 1s - loss: 0.0098 - mean_absolute_percentage_error: 1626359.9886 - acc: 0.1111 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 3254452.7585 - val_acc: 0.1392
# Epoch 147/250
# 1s - loss: 0.0097 - mean_absolute_percentage_error: 1798236.0393 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 1328674.9478 - val_acc: 0.1392
# Epoch 148/250
# 1s - loss: 0.0098 - mean_absolute_percentage_error: 1491811.8970 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 1331886.0802 - val_acc: 0.1392
# Epoch 149/250
# 1s - loss: 0.0098 - mean_absolute_percentage_error: 1643818.7973 - acc: 0.1111 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 2231356.0418 - val_acc: 0.1392
# Epoch 150/250
# 1s - loss: 0.0097 - mean_absolute_percentage_error: 1534951.7374 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 1671824.5441 - val_acc: 0.1392
# Epoch 151/250
# 1s - loss: 0.0098 - mean_absolute_percentage_error: 1582673.3918 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 2869103.4281 - val_acc: 0.1392
# Epoch 152/250
# 1s - loss: 0.0098 - mean_absolute_percentage_error: 1806057.9184 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 1517691.3107 - val_acc: 0.1392
# Epoch 153/250
# 1s - loss: 0.0098 - mean_absolute_percentage_error: 1567221.3939 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 2273782.6712 - val_acc: 0.1392
# Epoch 154/250
# 1s - loss: 0.0096 - mean_absolute_percentage_error: 1674150.2988 - acc: 0.1111 - val_loss: 0.0083 - val_mean_absolute_percentage_error: 2708084.0182 - val_acc: 0.1392
# Epoch 155/250
# 1s - loss: 0.0099 - mean_absolute_percentage_error: 1535892.4215 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 1527382.6921 - val_acc: 0.1392
# Epoch 156/250
# 1s - loss: 0.0097 - mean_absolute_percentage_error: 1661619.7882 - acc: 0.1111 - val_loss: 0.0080 - val_mean_absolute_percentage_error: 3021961.7610 - val_acc: 0.1392
# Epoch 157/250
# 1s - loss: 0.0098 - mean_absolute_percentage_error: 1684593.3364 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 2146142.0523 - val_acc: 0.1392
# Epoch 158/250
# 1s - loss: 0.0096 - mean_absolute_percentage_error: 1633997.7421 - acc: 0.1111 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 2839361.6981 - val_acc: 0.1392
# Epoch 159/250
# 1s - loss: 0.0097 - mean_absolute_percentage_error: 1479453.6051 - acc: 0.1111 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 1253358.0629 - val_acc: 0.1392
# Epoch 160/250
# 1s - loss: 0.0095 - mean_absolute_percentage_error: 1779179.7887 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 1068189.4394 - val_acc: 0.1392
# Epoch 161/250
# 1s - loss: 0.0100 - mean_absolute_percentage_error: 1616934.7584 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 2039423.5353 - val_acc: 0.1392
# Epoch 162/250
# 1s - loss: 0.0097 - mean_absolute_percentage_error: 1584990.9045 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 2121207.5234 - val_acc: 0.1392
# Epoch 163/250
# 1s - loss: 0.0096 - mean_absolute_percentage_error: 1600559.5319 - acc: 0.1111 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 2308327.3875 - val_acc: 0.1392
# Epoch 164/250
# 1s - loss: 0.0096 - mean_absolute_percentage_error: 1909893.9259 - acc: 0.1111 - val_loss: 0.0086 - val_mean_absolute_percentage_error: 3467783.0993 - val_acc: 0.1392
# Epoch 165/250
# 1s - loss: 0.0097 - mean_absolute_percentage_error: 1458486.3736 - acc: 0.1111 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 3337301.6616 - val_acc: 0.1392
# Epoch 166/250
# 1s - loss: 0.0095 - mean_absolute_percentage_error: 1571443.7996 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 2153273.6774 - val_acc: 0.1392
# Epoch 167/250
# 1s - loss: 0.0097 - mean_absolute_percentage_error: 1612190.6986 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 2736694.8794 - val_acc: 0.1392
# Epoch 168/250
# 1s - loss: 0.0096 - mean_absolute_percentage_error: 1696216.1457 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 1980469.7724 - val_acc: 0.1392
# Epoch 169/250
# 1s - loss: 0.0096 - mean_absolute_percentage_error: 1517594.6083 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 1672433.9615 - val_acc: 0.1392
# Epoch 170/250
# 1s - loss: 0.0097 - mean_absolute_percentage_error: 1668380.5781 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 1979265.2916 - val_acc: 0.1392
# Epoch 171/250
# 1s - loss: 0.0095 - mean_absolute_percentage_error: 1750391.8802 - acc: 0.1111 - val_loss: 0.0079 - val_mean_absolute_percentage_error: 2599546.6949 - val_acc: 0.1392
# Epoch 172/250
# 1s - loss: 0.0095 - mean_absolute_percentage_error: 1789197.3266 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 1938826.0253 - val_acc: 0.1392
# Epoch 173/250
# 1s - loss: 0.0096 - mean_absolute_percentage_error: 1776885.7712 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 2592226.2512 - val_acc: 0.1392
# Epoch 174/250
# 1s - loss: 0.0094 - mean_absolute_percentage_error: 1513832.7096 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 1764315.7453 - val_acc: 0.1392
# Epoch 175/250
# 1s - loss: 0.0094 - mean_absolute_percentage_error: 1564083.9664 - acc: 0.1111 - val_loss: 0.0080 - val_mean_absolute_percentage_error: 3555071.3112 - val_acc: 0.1392
# Epoch 176/250
# 1s - loss: 0.0096 - mean_absolute_percentage_error: 1626372.5123 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 1620788.4164 - val_acc: 0.1392
# Epoch 177/250
# 2s - loss: 0.0093 - mean_absolute_percentage_error: 1603248.9190 - acc: 0.1111 - val_loss: 0.0100 - val_mean_absolute_percentage_error: 4483019.9175 - val_acc: 0.1392
# Epoch 178/250
# 2s - loss: 0.0095 - mean_absolute_percentage_error: 1721462.6281 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 1959695.5105 - val_acc: 0.1392
# Epoch 179/250
# 1s - loss: 0.0095 - mean_absolute_percentage_error: 1738563.3480 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 3104406.3324 - val_acc: 0.1392
# Epoch 180/250
# 1s - loss: 0.0095 - mean_absolute_percentage_error: 1476070.8384 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 2533168.9645 - val_acc: 0.1392
# Epoch 181/250
# 1s - loss: 0.0094 - mean_absolute_percentage_error: 1803438.2570 - acc: 0.1111 - val_loss: 0.0079 - val_mean_absolute_percentage_error: 2619059.7350 - val_acc: 0.1392
# Epoch 182/250
# 1s - loss: 0.0095 - mean_absolute_percentage_error: 1482641.5323 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 1950796.3738 - val_acc: 0.1392
# Epoch 183/250
# 1s - loss: 0.0098 - mean_absolute_percentage_error: 1750690.8226 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 2058444.8358 - val_acc: 0.1392
# Epoch 184/250
# 1s - loss: 0.0093 - mean_absolute_percentage_error: 1633912.8981 - acc: 0.1111 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 2290228.2251 - val_acc: 0.1392
# Epoch 185/250
# 1s - loss: 0.0094 - mean_absolute_percentage_error: 1519913.8240 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 1688960.9940 - val_acc: 0.1392
# Epoch 186/250
# 1s - loss: 0.0095 - mean_absolute_percentage_error: 1528843.7914 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 1419449.4494 - val_acc: 0.1392
# Epoch 187/250
# 1s - loss: 0.0095 - mean_absolute_percentage_error: 1731020.6432 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 2263102.4406 - val_acc: 0.1392
# Epoch 188/250
# 1s - loss: 0.0095 - mean_absolute_percentage_error: 1560307.5156 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 1897423.0880 - val_acc: 0.1392
# Epoch 189/250
# 1s - loss: 0.0094 - mean_absolute_percentage_error: 1670366.6757 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 1969034.0858 - val_acc: 0.1392
# Epoch 190/250
# 1s - loss: 0.0094 - mean_absolute_percentage_error: 1622266.7976 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 2515918.5459 - val_acc: 0.1392
# Epoch 191/250
# 1s - loss: 0.0094 - mean_absolute_percentage_error: 1701999.3602 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 2055026.4066 - val_acc: 0.1392
# Epoch 192/250
# 1s - loss: 0.0094 - mean_absolute_percentage_error: 1765107.0522 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 2649735.3301 - val_acc: 0.1392
# Epoch 193/250
# 1s - loss: 0.0094 - mean_absolute_percentage_error: 1639894.6210 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 1950956.8430 - val_acc: 0.1392
# Epoch 194/250
# 1s - loss: 0.0094 - mean_absolute_percentage_error: 1581706.1489 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 2945868.2040 - val_acc: 0.1392
# Epoch 195/250
# 1s - loss: 0.0094 - mean_absolute_percentage_error: 1799313.2357 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 2418017.6892 - val_acc: 0.1392
# Epoch 196/250
# 1s - loss: 0.0093 - mean_absolute_percentage_error: 1711698.8225 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 2942498.7454 - val_acc: 0.1392
# Epoch 197/250
# 1s - loss: 0.0093 - mean_absolute_percentage_error: 1802657.9336 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 2455475.2616 - val_acc: 0.1392
# Epoch 198/250
# 1s - loss: 0.0093 - mean_absolute_percentage_error: 1383531.8551 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 3161324.9231 - val_acc: 0.1392
# Epoch 199/250
# 1s - loss: 0.0092 - mean_absolute_percentage_error: 1763063.6687 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 3210837.4333 - val_acc: 0.1392
# Epoch 200/250
# 1s - loss: 0.0092 - mean_absolute_percentage_error: 1820751.1798 - acc: 0.1111 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 1649483.2438 - val_acc: 0.1392
# Epoch 201/250
# 1s - loss: 0.0093 - mean_absolute_percentage_error: 1965072.2311 - acc: 0.1111 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 2933814.6218 - val_acc: 0.1392
# Epoch 202/250
# 1s - loss: 0.0093 - mean_absolute_percentage_error: 1546834.7594 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 3076490.7658 - val_acc: 0.1392
# Epoch 203/250
# 1s - loss: 0.0093 - mean_absolute_percentage_error: 1684465.5263 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 2402994.8244 - val_acc: 0.1392
# Epoch 204/250
# 1s - loss: 0.0092 - mean_absolute_percentage_error: 1675642.2012 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 2152317.8138 - val_acc: 0.1392
# Epoch 205/250
# 1s - loss: 0.0092 - mean_absolute_percentage_error: 1692983.7625 - acc: 0.1111 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 2114958.0517 - val_acc: 0.1392
# Epoch 206/250
# 1s - loss: 0.0092 - mean_absolute_percentage_error: 1623595.5321 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 2734571.6107 - val_acc: 0.1392
# Epoch 207/250
# 1s - loss: 0.0093 - mean_absolute_percentage_error: 1811942.7298 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 2191181.4838 - val_acc: 0.1392
# Epoch 208/250
# 1s - loss: 0.0092 - mean_absolute_percentage_error: 1546170.1539 - acc: 0.1111 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 2365838.5316 - val_acc: 0.1392
# Epoch 209/250
# 1s - loss: 0.0091 - mean_absolute_percentage_error: 1530990.5780 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 1762139.4930 - val_acc: 0.1392
# Epoch 210/250
# 1s - loss: 0.0091 - mean_absolute_percentage_error: 1810310.9375 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 3051390.8465 - val_acc: 0.1392
# Epoch 211/250
# 1s - loss: 0.0093 - mean_absolute_percentage_error: 1467761.9621 - acc: 0.1111 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 2179319.8037 - val_acc: 0.1392
# Epoch 212/250
# 1s - loss: 0.0093 - mean_absolute_percentage_error: 1775471.5170 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 2659238.0870 - val_acc: 0.1392
# Epoch 213/250
# 1s - loss: 0.0092 - mean_absolute_percentage_error: 1697720.8807 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 3659686.6728 - val_acc: 0.1392
# Epoch 214/250
# 1s - loss: 0.0092 - mean_absolute_percentage_error: 1659373.4234 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 3487247.0015 - val_acc: 0.1392
# Epoch 215/250
# 1s - loss: 0.0091 - mean_absolute_percentage_error: 1707272.9228 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 2790529.6644 - val_acc: 0.1392
# Epoch 216/250
# 1s - loss: 0.0090 - mean_absolute_percentage_error: 1528806.0272 - acc: 0.1111 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 2414961.3179 - val_acc: 0.1392
# Epoch 217/250
# 1s - loss: 0.0090 - mean_absolute_percentage_error: 1938464.5546 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 1627837.7712 - val_acc: 0.1392
# Epoch 218/250
# 1s - loss: 0.0091 - mean_absolute_percentage_error: 1801656.7705 - acc: 0.1111 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 2361181.0139 - val_acc: 0.1392
# Epoch 219/250
# 1s - loss: 0.0091 - mean_absolute_percentage_error: 1642811.2923 - acc: 0.1111 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 1880451.3757 - val_acc: 0.1392
# Epoch 220/250
# 1s - loss: 0.0090 - mean_absolute_percentage_error: 1460788.4376 - acc: 0.1111 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 2196457.1402 - val_acc: 0.1392
# Epoch 221/250
# 1s - loss: 0.0090 - mean_absolute_percentage_error: 1784583.0724 - acc: 0.1111 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 2391632.2240 - val_acc: 0.1392
# Epoch 222/250
# 1s - loss: 0.0088 - mean_absolute_percentage_error: 1893036.7841 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 3135379.5369 - val_acc: 0.1392
# Epoch 223/250
# 1s - loss: 0.0092 - mean_absolute_percentage_error: 1794293.6763 - acc: 0.1111 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 2560159.8417 - val_acc: 0.1392
# Epoch 224/250
# 1s - loss: 0.0092 - mean_absolute_percentage_error: 1811261.7252 - acc: 0.1111 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 2412249.0605 - val_acc: 0.1392
# Epoch 225/250
# 1s - loss: 0.0091 - mean_absolute_percentage_error: 1550831.5605 - acc: 0.1111 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 2328457.3375 - val_acc: 0.1392
# Epoch 226/250
# 1s - loss: 0.0089 - mean_absolute_percentage_error: 1655640.2099 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 1710884.0162 - val_acc: 0.1392
# Epoch 227/250
# 1s - loss: 0.0090 - mean_absolute_percentage_error: 1802901.1166 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 3231618.3490 - val_acc: 0.1392
# Epoch 228/250
# 1s - loss: 0.0090 - mean_absolute_percentage_error: 1694770.4032 - acc: 0.1111 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 2418109.9602 - val_acc: 0.1392
# Epoch 229/250
# 1s - loss: 0.0090 - mean_absolute_percentage_error: 1594149.6788 - acc: 0.1111 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 2117804.5379 - val_acc: 0.1392
# Epoch 230/250
# 2s - loss: 0.0089 - mean_absolute_percentage_error: 1878588.0012 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 2812302.6494 - val_acc: 0.1392
# Epoch 231/250
# 1s - loss: 0.0091 - mean_absolute_percentage_error: 1651544.5848 - acc: 0.1111 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 2767718.2426 - val_acc: 0.1392
# Epoch 232/250
# 1s - loss: 0.0090 - mean_absolute_percentage_error: 1606349.5001 - acc: 0.1111 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 2696631.5664 - val_acc: 0.1392
# Epoch 233/250
# 1s - loss: 0.0089 - mean_absolute_percentage_error: 1687305.8716 - acc: 0.1111 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 2521509.1633 - val_acc: 0.1392
# Epoch 234/250
# 1s - loss: 0.0089 - mean_absolute_percentage_error: 1759691.8350 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 2286864.5165 - val_acc: 0.1392
# Epoch 235/250
# 1s - loss: 0.0090 - mean_absolute_percentage_error: 1830699.8157 - acc: 0.1111 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 2217121.4816 - val_acc: 0.1392
# Epoch 236/250
# 1s - loss: 0.0089 - mean_absolute_percentage_error: 1578422.9769 - acc: 0.1111 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 2270222.5170 - val_acc: 0.1392
# Epoch 237/250
# 1s - loss: 0.0089 - mean_absolute_percentage_error: 1607963.3849 - acc: 0.1111 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 2736681.8898 - val_acc: 0.1392
# Epoch 238/250
# 1s - loss: 0.0090 - mean_absolute_percentage_error: 1859950.1011 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 3515648.6485 - val_acc: 0.1392
# Epoch 239/250
# 1s - loss: 0.0086 - mean_absolute_percentage_error: 1807924.4872 - acc: 0.1111 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 1790404.9438 - val_acc: 0.1392
# Epoch 240/250
# 1s - loss: 0.0090 - mean_absolute_percentage_error: 1731938.4785 - acc: 0.1111 - val_loss: 0.0082 - val_mean_absolute_percentage_error: 3679176.8908 - val_acc: 0.1392
# Epoch 241/250
# 1s - loss: 0.0090 - mean_absolute_percentage_error: 1672347.1536 - acc: 0.1111 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 2296002.3616 - val_acc: 0.1392
# Epoch 242/250
# 1s - loss: 0.0088 - mean_absolute_percentage_error: 1744020.6104 - acc: 0.1111 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 1692307.7906 - val_acc: 0.1392
# Epoch 243/250
# 1s - loss: 0.0089 - mean_absolute_percentage_error: 1677862.0450 - acc: 0.1111 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 2213884.8219 - val_acc: 0.1392
# Epoch 244/250
# 1s - loss: 0.0087 - mean_absolute_percentage_error: 1769121.9581 - acc: 0.1111 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 3366066.3105 - val_acc: 0.1392
# Epoch 245/250
# 1s - loss: 0.0089 - mean_absolute_percentage_error: 1546895.4659 - acc: 0.1111 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 2375793.0003 - val_acc: 0.1392
# Epoch 246/250
# 1s - loss: 0.0088 - mean_absolute_percentage_error: 1804804.0723 - acc: 0.1111 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 1834867.8980 - val_acc: 0.1392
# Epoch 247/250
# 1s - loss: 0.0089 - mean_absolute_percentage_error: 1740895.7913 - acc: 0.1111 - val_loss: 0.0071 - val_mean_absolute_percentage_error: 2403890.6408 - val_acc: 0.1392
# Epoch 248/250
# 1s - loss: 0.0088 - mean_absolute_percentage_error: 1775735.8417 - acc: 0.1111 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 2805896.7598 - val_acc: 0.1392
# Epoch 249/250
# 1s - loss: 0.0089 - mean_absolute_percentage_error: 1660924.9403 - acc: 0.1111 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 2541982.4316 - val_acc: 0.1392
# Epoch 250/250
# 1s - loss: 0.0088 - mean_absolute_percentage_error: 1760940.0195 - acc: 0.1111 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 2119548.7122 - val_acc: 0.1392
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\utils\vis_utils.py in _check_pydot()
#      22         # to check the pydot/graphviz installation.
# ---> 23         pydot.Dot.create(pydot.Dot())
#      24     except Exception:
#
# AttributeError: 'NoneType' object has no attribute 'Dot'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-23-c02cf5f9116d> in <module>
#      15 #fit the model
#      16 model1, history = fit_model(train_X, train_Y, window_size)
# ---> 17 plot_model(model1, to_file='LSTM_Latur_plot_1.png', show_shapes=True, show_layer_names=True)
#      18 model1.summary()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\utils\vis_utils.py in plot_model(model, to_file, show_shapes, show_layer_names, rankdir)
#     129             'LR' creates a horizontal plot.
#     130     """
# --> 131     dot = model_to_dot(model, show_shapes, show_layer_names, rankdir)
#     132     _, extension = os.path.splitext(to_file)
#     133     if not extension:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\utils\vis_utils.py in model_to_dot(model, show_shapes, show_layer_names, rankdir)
#      50     from ..models import Sequential
#      51
# ---> 52     _check_pydot()
#      53     dot = pydot.Dot()
#      54     dot.set('rankdir', rankdir)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\utils\vis_utils.py in _check_pydot()
#      25         # pydot raises a generic Exception here,
#      26         # so no specific class can be caught.
# ---> 27         raise ImportError('Failed to import pydot. You must install pydot'
#      28                           ' and graphviz for `pydotprint` to work.')
#      29
#
# ImportError: Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %% [markdown]
# <h2>Results</h2>

# %% [markdown]
# <b>Predictions and model evaluation</b>

# %%
train_Y.shape
# Out:
# (351, 1)

# %%
test_Y.shape
# Out:
# (79, 1)

# %%
def predict_and_score(model,X,Y):
    #Make predictions on the original scale of data
    pred = scaler.inverse_transform(model.predict(X))
    #Prepare Y also to be in original data scale
    orig_data = scaler.inverse_transform(Y)
#     print(orig_data)
#     print("-----")
#     print(pred[:,0])
    #Calculate RMSE
    score = math.sqrt(mean_squared_error(orig_data, pred[:, 0]))
    return (score,pred)

train_rmse, train_predict = predict_and_score(model1, train_X, train_Y)
test_rmse, test_predict = predict_and_score(model1, test_X, test_Y)

# train_rmse, train_predict = predict_and_score(model1, train_X, np.reshape(train_Y, (train_Y.shape[0], 1,1)))
# test_rmse, test_predict = predict_and_score(model1, test_X, np.reshape(test_Y, (test_Y.shape[0],1, 1)))

print("Training data score: %.2f RMSE" % train_rmse)
print("Test data score: %.2f RMSE" % test_rmse)
# Out:
# Training data score: 42.54 RMSE
# Test data score: 39.24 RMSE

# %%
# start with training predictions
train_predict_plot = np.empty_like(dataset)
train_predict_plot[:,:] = np.nan
train_predict_plot[window_size:len(train_predict) + window_size, :] = train_predict

# Add test predictions.
test_predict_plot = np.empty_like(dataset)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(train_predict) + (window_size * 2) + 1:len(dataset) - 1, :] = test_predict

# %%
# Create the plot.
plt.figure(figsize = (15, 5))
plt.plot(scaler.inverse_transform(dataset), label = "True value")
plt.plot(train_predict_plot, label = "Training set prediction")
plt.plot(test_predict_plot, label = "Test set prediction")
plt.xlabel("Months")
plt.ylabel("")
plt.title("Latur Rainfall Data Prediction")
plt.legend()
plt.show()

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()



# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_percentage_error', 'val_acc', 'loss', 'mean_absolute_percentage_error', 'acc'])

# %%
print("Training data score: %.2f RMSE" % train_rmse)
print("Test data score: %.2f RMSE" % test_rmse)
# Out:
# Training data score: 42.54 RMSE
# Test data score: 39.24 RMSE
